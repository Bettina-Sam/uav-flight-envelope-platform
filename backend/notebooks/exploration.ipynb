# %% [markdown]
# # UAV Flight Envelope — Exploratory Notebook
#
# Optional notebook for exploring the synthetic dataset and physics engine interactively.
# Run `pip install -r ../requirements.txt jupyter` and `jupyter notebook` from this folder.

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
import pandas as pd
from app import physics

df = pd.read_csv('../data/uav_synthetic_dataset.csv')
df.describe()
